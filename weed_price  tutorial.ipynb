# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
df =pd.read_csv("D:\Shubham\Weed_Price.csv")
df
# Out:
#                State   HighQ  HighQN    MedQ  MedQN    LowQ  LowQN        date
# 0            Alabama  339.06    1042  198.64    933  149.49    123  2014-01-01
# 1             Alaska  288.75     252  260.60    297  388.58     26  2014-01-01
# 2            Arizona  303.31    1941  209.35   1625  189.45    222  2014-01-01
# 3           Arkansas  361.85     576  185.62    544  125.87    112  2014-01-01
# 4         California  248.78   12096  193.56  12812  192.92    778  2014-01-01
# ...              ...     ...     ...     ...    ...     ...    ...         ...
# 22894       Virginia  364.98    3513  293.12   3079     NaN    284  2014-12-31
# 22895     Washington  233.05    3337  189.92   3562     NaN    160  2014-12-31
# 22896  West Virginia  359.35     551  224.03    545     NaN     60  2014-12-31
# 22897      Wisconsin  350.52    2244  272.71   2221     NaN    167  2014-12-31
# 22898        Wyoming  322.27     131  351.86    197     NaN     12  2014-12-31
#
# ...

# %%
#From datetime stamp variable ,Seperate month and year and develop new fearture. 

df['Year']=pd.DatetimeIndex(df['date']).year
df['Month']=pd.DatetimeIndex(df['date']).month

# %%
df.head()
# Out:
#         State   HighQ  HighQN    MedQ  MedQN    LowQ  LowQN        date  Year  \
# 0     Alabama  339.06    1042  198.64    933  149.49    123  2014-01-01  2014
# 1      Alaska  288.75     252  260.60    297  388.58     26  2014-01-01  2014
# 2     Arizona  303.31    1941  209.35   1625  189.45    222  2014-01-01  2014
# 3    Arkansas  361.85     576  185.62    544  125.87    112  2014-01-01  2014
# 4  California  248.78   12096  193.56  12812  192.92    778  2014-01-01  2014
#
#    Month
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
df.describe()
# Out:
#               HighQ        HighQN          MedQ         MedQN          LowQ  \
# count  22899.000000  22899.000000  22899.000000  22899.000000  12342.000000
# mean     329.759854   2274.743657    247.618306   2183.737805    203.747847
# std       41.173167   2641.936586     44.276015   2789.902626    105.480774
# min      202.020000     93.000000    144.850000    134.000000     63.700000
# 25%      303.780000    597.000000    215.775000    548.000000    147.117500
# 50%      342.310000   1420.000000    245.800000   1320.000000    186.760000
# 75%      356.550000   2958.000000    274.155000   2673.000000    221.360000
# max      415.700000  18492.000000    379.000000  22027.000000    734.650000
#
#               LowQN          Year         Month
# count  22899.000000  22899.000000  22899.000000
# mean     202.804489   2014.167038      5.953229
# std      220.531987      0.401765      3.553055
# min       11.000000   2013.000000      1.000000
# ...

# %%
df.head()
# Out:
#         State   HighQ  HighQN    MedQ  MedQN    LowQ  LowQN        date  Year  \
# 0     Alabama  339.06    1042  198.64    933  149.49    123  2014-01-01  2014
# 1      Alaska  288.75     252  260.60    297  388.58     26  2014-01-01  2014
# 2     Arizona  303.31    1941  209.35   1625  189.45    222  2014-01-01  2014
# 3    Arkansas  361.85     576  185.62    544  125.87    112  2014-01-01  2014
# 4  California  248.78   12096  193.56  12812  192.92    778  2014-01-01  2014
#
#    Month
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
# groupby() function is used to split the data into groups based on given criteria.

# %%
gr=df.groupby('Month')
gr.first()
# Out:
#          State   HighQ  HighQN    MedQ  MedQN    LowQ  LowQN        
ighQ  HighQN    MedQ  MedQN    LowQ  LowQN        date  \
# Year State
# 2013 Alabama        339.65    1033  198.04    926  147.15    122  2013-12-27
#      Alaska         288.75     252  260.82    296  388.58     26  2013-12-27
#      Arizona        303.52    1934  209.19   1619  189.45    222  2013-12-27
#      Arkansas       361.78     575  184.90    543  125.87    112  2013-12-27
#      California     248.77   12021  193.44  12724  193.88    770  2013-12-27
# ...                    ...     ...     ...    ...     ...    ...         ...
# 2015 Virginia       364.95    3514  293.02   3085     NaN    285  2015-01-01
#      Washington     233.01    3341  189.92   3564     NaN    160  2015-01-01
#      West Virginia  359.63     552  224.17    546     NaN     60  2015-01-01
#      Wisconsin      350.49    2246  272.73   2222     NaN    167  2015-01-01
#      Wyoming        320.39     133  351.86    197     NaN     12  2015-01-01
#
#                     Month
# ...

# %%
gr= df.groupby(['Month', 'HighQ'])
gr.first()
# Out:
#                      State  HighQN    MedQ  MedQN    LowQ  LowQN        date  \
# Month HighQ
# 1     205.19        Oregon    2224  180.65   2084     NaN     99  2015-01-28
#       205.27        Oregon    2223  180.59   2081     NaN     99  2015-01-26
#       205.30        Oregon    2222  180.50   2078     NaN     99  2015-01-23
#       205.33        Oregon    2231  180.47   2091     NaN     99  2015-01-31
#       205.35        Oregon    2219  180.66   2074     NaN     99  2015-01-22
# ...                    ...     ...     ...    ...     ...    ...         ...
# 12    397.09  North Dakota     204  345.27    311     NaN     23  2014-12-01
#       397.32  North Dakota     206  345.93    313     NaN     23  2014-12-08
#       412.81  North Dakota     135  361.62    198  269.55     13  2013-12-30
#       412.84  North Dakota     137  361.26    199  269.55     13  2013-12-31
#       415.70  North Dakota     134  361.62    198  269.55     13  2013-12-27
#
#               Year
# ...

# %%
sns.lineplot(x='Month', y='HighQ', data=df, color='y')
plt.show()
sns.lineplot(x='Year', y='HighQ', data=df, color='r')
plt.show()

# %%
sns.set_style('whitegrid')
sns.histplot(x='Month', y='HighQN', data=df, color='r')
plt.show()
sns.histplot(x='Year', y='HighQN', data=df, color='y')
plt.show()

# %%
sns.set_style('whitegrid')
sns.distplot(df['HighQ'],kde=False,color='red', bins=25)
# kde is Kernel Dencity Estimatiom and that is another kind of plot in seaborn
print('This HighQ Histogram shows left Skiwness')
# Out:
# This HighQ Histogram shows left Skiwness

# %%
sns.displot(df['HighQ'], kind='kde',color='r')  #Right Skiwness
sns.displot(df['HighQN'], kind='kde',color='y') #Left Skiwness
sns.displot(df['MedQ'], kind='kde',color='r')  #Normal Distrubution
sns.displot(df['MedQN'], kind='kde',color='y') #Kortosis
sns.displot(df['LowQ'], kind='kde',color='g')  #Kortosis
sns.displot(df['LowQN'],kind='kde',color='b')  #Left Skiwness

# %%
sns.distplot(df['HighQN'],kde=False,color='red', bins=25)
print('HighQN shows the Left Skiwness')
# Out:
# HighQN shows the Left Skiwness

# %% [markdown]
# # Joinplot #

# %%
sns.jointplot(x='HighQ',y='HighQN',data=df,color='y')

# %%
# KDE shows the density where the pointd match up the most.

sns.jointplot(x='HighQ',y='HighQN',data=df,color='r', kind='kde')

# %% [markdown]
# # pairplot #

# %%
sns.pairplot(df,hue='Month',palette='coolwarm')

# %%
sns.lineplot(x='HighQ',y='HighQN',data=df)
plt.show()

# %%
sns.scatterplot(x='HighQ',y='HighQN',data=df,color='r')
plt.show()

# %%
sns.barplot(x='Year', y='HighQ', data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Box Plot
sns.boxplot(df['HighQ'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='HighQ'>

# %%
# Position of the Outlier 
# It shows that the outlier lies below 250
print(np.where(df['HighQ']<250))
# Out:
# (array([    4,     5,    31, ..., 22853, 22879, 22895], dtype=int64),)

# %%
# Scatter plot for detection of outlier
fig, ax = plt.subplots(figsize=(18,10))
ax.scatter(df['Year'],df['HighQ'])
ax.set_xlabel('Year')
ax.set_ylabel('HighQ')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# In scatter plot shows the year wise outlier ,using appox we can say that in 2013 (outlier<250),
#  in 2014 (outlier <250), in 2015 (outlier<250 & outlier>375)

# %%
# Z Score = This value/score helps to understand that the how far is data point from mean.
#  Zscore=(data_point-mean/std.deviation)
from scipy import stats
z =np.abs(stats.zscore(df['HighQ']))
z
# Out:
# 0        0.225884
# 1        0.996055
# 2        0.642419
# 3        0.779412
# 4        1.966854
#            ...
# 22894    0.855434
# 22895    2.348908
# 22896    0.718691
# 22897    0.504226
# 22898    0.181915
# Name: HighQ, Length: 22899, dtype: float64

# %%
# Position of outliers
threshold = 3
print(np.where(z > 3))
# Out:
# (array([   82,   184,   439,   847,   949,  1204,  1561,  1663,  1918,
#         2326,  2428,  2683,  3091,  3193,  3448,  3856,  3958,  4213,
#         4621,  4723,  4978,  5386,  5488,  5743,  6151,  6253,  6508,
#         6916,  7018,  7222,  7324,  7732,  7834,  8038,  8140,  8548,
#         8650,  8854,  9313,  9415,  9619, 10078, 10180, 10384, 10843,
#        10945, 11149, 11608, 11710, 11914, 12373, 12628, 13087, 13342,
#        13801, 14056, 14515, 14770, 15127, 15229, 15484, 15841, 15943,
#        16198, 16555, 16657, 16912, 17269, 17371, 17626, 17983, 18085,
#        18340, 18697, 18799, 19054, 19411, 19513, 19768, 20176, 20278,
#        20533, 20941, 21043, 21247, 21655, 21757, 21961, 22369, 22471,
#        22624, 22879], dtype=int64),)

# %%
# IQR(Inter Quartile Range) approach to finding the outlier is the most commonly used 
# and most trusted approach used in research field.
# IQR = Quartile3 - Quartile1
Q1 = np.percentile(df['HighQ'], 25, interpolation = 'midpoint')
Q3 = np.percentile(df['HighQ'], 75, interpolation = 'midpoint')
IQR = Q3 - Q1
print('IQR:',IQR,'Q1:',Q1,'Q3:',Q3)
# Out:
# IQR: 52.77000000000004 Q1: 303.78 Q3: 356.55
